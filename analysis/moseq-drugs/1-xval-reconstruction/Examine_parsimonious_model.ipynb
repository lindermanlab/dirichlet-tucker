# %% [markdown]
# In `Analyze_cross_validation_results.ipynb`, we identify the most parsimonious model to be of sizes 16 dynamic topics, with the dynamic topics consisting of 8 temporal bases and 24 behavioral topics, $(k_1=16, k_2=8, k_3=24)$. In this notebook, we analyze the model stablity and inspect the elements.

# %%
# %load_ext autoreload
# %autoreload 2

# %load_ext dotenv
# %dotenv
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
